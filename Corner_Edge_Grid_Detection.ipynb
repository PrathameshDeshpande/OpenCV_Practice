# %%
# Corner Detection
import cv2 
import numpy as np  
import matplotlib.pyplot as plt

# %%
Chess_img = cv2.cvtColor(cv2.imread('flat_chessboard.png'),cv2.COLOR_BGR2RGB)
plt.imshow(Chess_img)

# %%
gray_flat_chess = cv2.cvtColor(Chess_img,cv2.COLOR_BGR2GRAY)
plt.imshow(gray_flat_chess,'gray')

# %%
BLUE = [255,255,255]
padded_chess_img_gray = cv2.copyMakeBorder(gray_flat_chess.copy(),25,25,25,25,cv2.BORDER_CONSTANT,value=BLUE)
plt.imshow(padded_chess_img_gray,'gray')

# %%
corners = cv2.goodFeaturesToTrack(padded_chess_img_gray,100,0.1,10)
corners =np.int0(corners)

# %%
for i in corners:
    x,y = i.ravel()
    cv2.circle(padded_chess_img_gray,(x,y),3,(0,255,0),-1)

plt.imshow(padded_chess_img_gray,"gray")

# %%
# EDGE DETECTION THROUGH OPENCV

img = cv2.imread('Bruno_face.jpg')
blurred_img = cv2.blur(img,ksize=(5,5))
med_val = np.mean(blurred_img)
lower = int(max(0, 0.7* med_val))
upper = int(min(255,1.3 * med_val))
edges = cv2.Canny(image=blurred_img, threshold1=lower+20 , threshold2=upper+45)
fig = plt.figure(figsize=(10,8))
plt.subplot(121)
plt.imshow(img)
plt.subplot(122)
plt.imshow(edges)

# %%
img = cv2.imread('Bruno.jpg')
blurred_img = cv2.blur(img,ksize=(5,5))
med_val = np.mean(blurred_img)
lower = int(max(0, 0.7* med_val))
upper = int(min(255,1.3 * med_val))
edges = cv2.Canny(image=blurred_img, threshold1=lower+35 , threshold2=upper+45)

# %%
fig = plt.figure(figsize=(10,8))
plt.subplot(121)
plt.imshow(img)
plt.subplot(122)
plt.imshow(edges)

# %%
#Grid_Detection
img = cv2.imread('flat_chessboard.png')
plt.imshow(cv2.imread('flat_chessboard.png'),cmap='gray')
found, corners = cv2.findChessboardCorners(img,(7,7))
if found:
    print('OpenCV was able to find the corners')
else:
    print("OpenCV did not find corners. Please check your patternSize.")
# Out:
# OpenCV was able to find the corners

# %%
cv2.drawChessboardCorners(img,(7,7),corners,found)
plt.imshow(img)
